# %%
import pandas as pd

#reading data from csv file
data1 = pd.read_csv("CryptoData.csv")
data2 = pd.read_csv("Top-Apps-in-Google-Play.csv")
data3 = pd.read_csv("programming language trend over time.csv")

df1 = data1.iloc[:7]
df2 = data2.iloc[:7]
df3 = data3.iloc[:7]

print("First 7 rows of Cryptodata.csv:")
print("")
print(df1)

print("")
print("")
print("First 7 rows of Top-Apps-in-Google-Play.csv:")
print("")
print(df2)

print("")
print("")
print("First 7 rows of programming language trend over time.csv:")
print("")
print(df3)

df11 = data1.iloc[:, :3]
df21 = data2.iloc[:, :3]
df31 = data3.iloc[:, :3]

print("")
print("")
print("First 3 columns of Top-Apps-in-Google-Play.csv:")
print("")
print(df11)

print("")
print("")
print("First 3 columns of programming language trend over time.csv:")
print("")
print(df21)

print("")
print("")
print("First 3 columns of CryptoData.csv:")
print("")
print(df31)

df13 = data1.head(1)
df23 = data2.head(1)
df33 = data3.head(1)

print("")
print(df13)
print("")

print("")
print(df23)
print("")

print("")
print(df33)
print("")
# Out:
# First 7 rows of Cryptodata.csv:
#
#         Date    Price     Open     High      Low     Vol. Change %
# 0  25-Mar-22  44331.0  44013.0  45112.0  43622.0  494.09M    0.72%
# 1  24-Mar-22  44013.0  42911.0  44251.0  42658.0  491.66M    2.57%
# 2  23-Mar-22  42912.0  42373.0  43027.0  41795.0  433.96M    1.27%
# 3  22-Mar-22  42373.0  41022.0  43327.9  40893.0  537.06M    3.29%
# 4  21-Mar-22  41022.0  41282.0  41532.0  40530.0  406.62M   -0.62%
# 5  20-Mar-22  41276.0  42241.0  42301.0  40922.0  308.45M   -2.27%
# 6  19-Mar-22  42233.0  41768.0  42386.0  41529.6  224.59M    1.11%
#
#
# First 7 rows of Top-Apps-in-Google-Play.csv:
#
#    Unnamed: 0                          App Name  \
# 0           1              Google Play services
# 1           2                           YouTube
# 2           3                            Google
# 3           4  Google Maps - Navigate & Explore
# 4           5             Google Text-to-Speech
# 5           6      Google Chrome: Fast & Secure
# ...

# %%
import pandas as pd

cadbury_market = {'Products': ['Bournvita','Hot Chocolate','Cocoa Butter','Cake','Liquor','Powder', 'Tom Tom', 'Buttermint'],
           'Segments': ['Refreshment Beverages','Refreshment Beverages','Intermediate Cocoa Products','Intermediate Cocoa Products','Intermediate Cocoa Products','Intermediate Cocoa Products','Confectionery','Confectionery'],
           'Exports' : ['','','International','International','International','Local','',''],
           'Brands'  : ['Cadbury Bournvita','Cadbury 3-in-1 Hot Chocolate','Cocoa Butter','','','Cocoa Powder','TomTom Classic/Strawberry','Buttermint']}
           

df = pd.DataFrame(cadbury_market)
df.to_csv('cadbury_market.csv')
