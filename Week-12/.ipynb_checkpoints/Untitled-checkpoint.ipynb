# %%
import tkinter as tk
from tkinter import messagebox

class  External_Vendors(ABC):

    @abstractmethod
    def menu(self):
        pass

class Cooperative_Cafeteria(External_Vendors):
    
    def menu(self):
    window2 = tk.Toplevel(window1)
    window2.title("Menu Window")
    window2.geometry("500x500")

    l1 = tk.Label(window2, text = "COOPERATIVE CAFETERIA MENU")
    l1.pack()

    l3 = tk.Label(window2, text = "Jollof Rice and Stew       200")
    l3.pack()

    l4 = tk.Label(window2, text = "White Rice and Stew        200")
    l4.pack()

    l5 = tk.Label(window2, text = "Fried Rice                 200")
    l5.pack()

    l6 = tk.Label(window2, text = "Salad                      100")
    l6.pack()

    l7 = tk.Label(window2, text = "Plantain                   100")
    l7.pack()

    window1.mainloop()
    
class Faith_Hostel_Cafeteria(External_Vendors):
    
    def menu(self):
    window2 = tk.Toplevel(window1)
    window2.title("Menu Window")
    window2.geometry("500x500")

    l1 = tk.Label(window2, text = "COOPERATIVE CAFETERIA MENU")
    l1.pack()

    l3 = tk.Label(window2, text = "Jollof Rice and Stew       400")
    l3.pack()

    l4 = tk.Label(window2, text = "White Rice and Stew        400")
    l4.pack()

    l5 = tk.Label(window2, text = "Fried Rice                 400")
    l5.pack()

    l6 = tk.Label(window2, text = "Beans                      200")
    l6.pack()

    l7 = tk.Label(window2, text = "Chicken                    100")
    l7.pack()

    window1.mainloop()

class Faith_Hostel_Cafeteria( External_Vendors):
    
    def menu(self):
    window2 = tk.Toplevel(window1)
    window2.title("Menu Window")
    window2.geometry("500x500")

    l1 = tk.Label(window2, text = "COOPERATIVE CAFETERIA MENU")
    l1.pack()

    l3 = tk.Label(window2, text = "Chicken Fried Rice         800")
    l3.pack()

    l4 = tk.Label(window2, text = "Pomo Sauce                 300")
    l4.pack()

    l5 = tk.Label(window2, text = "Spaghetti Jollof             500")
    l5.pack()

    l6 = tk.Label(window2, text = "Amala/Ewedu                500")
    l6.pack()

    l7 = tk.Label(window2, text = "Semo with Eforiro Soup     500")
    l7.pack()

    window1.mainloop()

def enter():
# Out:
#   Cell In[1], line 13
#     window2 = tk.Toplevel(window1)
#     ^
# IndentationError: expected an indented block after function definition on line 11
