# %%
import tkinter as tk
from tkinter import messagebox

price1_entry = {}
price2_entry = {}
price3_entry = {}
price4_entry = {}
price5_entry = {}


def menu():
    #menu window
    window2 = tk.Toplevel(window1)
    window2.title("Menu Window")
    window2.geometry("600x900")

    #l1 = tk.Label(window2, text = "MENU")
    #l1.pack()
    
    l2 = tk.Label(window2, text = "RICE/PASTA")
    l2.pack()

    l3 = tk.Label(window2, text = "Jollof Rice                   350")
    l3.pack()

    l4 = tk.Label(window2, text = "Coconut Jollof Rice    350")
    l4.pack()

    l5 = tk.Label(window2, text = "Jollof Spaghetti          350\n")
    l5.pack()

    l6 = tk.Label(window2, text = "SIDE DISHES")
    l6.pack()

    l7 = tk.Label(window2, text = "Savoury Beans                  350")
    l7.pack()

    l8 = tk.Label(window2, text = "Roasted Sweet Potatoes   300")
    l8.pack()

    l9 = tk.Label(window2, text = "Fried Plantain                  150")
    l9.pack()

    l10 = tk.Label(window2, text = "Mixed Vegetable Salad    150")
    l10.pack()

    l11 = tk.Label(window2, text = "Boiled Yam                    150\n")
    l11.pack()

    l12 = tk.Label(window2, text = "SOUPS & SWALLOWS")
    l12.pack()

    l13 = tk.Label(window2, text = "Eba                           150")
    l13.pack()

    l14 = tk.Label(window2, text = "Poundo Yam            100")
    l14.pack()

    l15 = tk.Label(window2, text = "Semo                        100")
    l15.pack()

    l16= tk.Label(window2, text = "Atama Soup              450")
    l16.pack()

    l17= tk.Label(window2, text = "Egusi Soup                480\n")
    l17.pack()

    l18 = tk.Label(window2, text = "PROTEINS")
    l18.pack()

    l19 = tk.Label(window2, text = "Sweet Chill Chicken      1100")
    l19.pack()

    l20 = tk.Label(window2, text = "Grilled Chicken Wings  400")
    l20.pack()
 
    l21 = tk.Label(window2, text = "Fried beef                      400")
    l21.pack()

    l22 = tk.Label(window2, text = "Fried Fish                      400")
    l22.pack()

    l23 = tk.Label(window2, text = "Boiled Egg                     500")
    l23.pack()

    l24 = tk.Label(window2, text = "Sauteed Sausages         200\n")
    l24.pack()

    l25= tk.Label(window2, text = "BEVERAGES")
    l25.pack()

    l26 = tk.Label(window2, text = "Water                        200")
    l26.pack()

    l27= tk.Label(window2, text = "Glass Drink                150")
    l27.pack()

    l28= tk.Label(window2, text = "PET drink (35cl)          300")
    l28.pack()

    l29= tk.Label(window2, text = "PET drink (50cl)          350")
    l29.pack()

    l2= tk.Label(window2, text = "Glass/Canned Malt    500")
    l2.pack()

    l2= tk.Label(window2, text = "Fresh Yo                     600")
    l2.pack()

    l30= tk.Label(window2, text = "Pineapple Juice          350")
    l30.pack()

    l30= tk.Label(window2, text = "Mango Juice              350")
    l30.pack()

    l30= tk.Label(window2, text = "Zobo Drink               350")
    l30.pack()

    #l30= tk.Label(window2, text = "ENJOY")
    #l30.pack()

    order_button = tk.Button(window2, text = "Place Order", command=order)
    order_button.pack()  
    
    window1.mainloop()

def discount1():
    d1 = 0.1 * total_price
    d2 = total_price - d1
    messagebox.showinfo("Discounted Price",f"The new price of your order is : N{d2}")

def discount2():
    d3 = 0.15 * total_price
    d4 = total_price - d3
    messagebox.showinfo("Discounted Price",f"The new price of your order is : N{d4}")

def discount3():
    d5 = 0.25 * total_price
    d6 = total_price - d5
    messagebox.showinfo("Discounted Price",f"The new price of your order is : N{d6}")
    

def enter1():
    global total_price

    order1 = order1_entry.get()
    order2 = order2_entry.get()
    order3 = order3_entry.get()
    order4 = order4_entry.get()
    order5 = order5_entry.get()
   

    price1 = float(price1_entry.get())
    price2 = float(price2_entry.get())
    price3 = float(price3_entry.get())
    price4 = float(price4_entry.get())
    price5 = float(price5_entry.get())

    total_price = price1 + price2 + price3 + price4 + price5
    messagebox.showinfo("Total Price", f"The total price of your order is : N{total_price}")

    if total_price < 2500.0:
        discount1()

    elif total_price > 2500.0 and total_price < 5000.0 :
        discount2()

    elif total_price > 5000.0:
        discount3()

    elif total_price < 1000.0:
         messagebox.showinfo('Discount not granted','Make a purchase above N1000 to get a discount')

    else:
        messagebox.showinfo('Discount not granted','Make a purchase to get a discount')
        
    window1.mainloop()

def order():
    #order window
    window3 = tk.Toplevel(window1)
    window3.title("Order Window")
    window3.geometry("600x00")

    l1 = tk.Label(window3, text = "Welcome to the checkout window:") 
    l1.pack()

    l2 = tk.Label(window3, text = "Feel free to order what you want:") 
    l2.pack()

    l1 = tk.Label(window3, text = "You can do this by typing the preferred meal of your choice and it's respective price in the boxes below:") 
    l1.pack()

    l1 = tk.Label(window3, text = "In the boxes that require a price input 0 if you do not want to other anything else:") 
    l1.pack()

    l1 = tk.Label(window3, text = "In the boxes that require the meal you want leave blank if you do not want anything else :") 
    l1.pack()
    
    order1 = tk.Label(window3, text = "Type in what you want:") 
    order1.pack()
    global order1_entry
    order1_entry = tk.Entry(window3)
    order1_entry.pack()

    price1 = tk.Label(window3, text = "Type in the price:") 
    price1.pack()
    global price1_entry
    price1_entry = tk.Entry(window3)
    price1_entry.pack()
    
    order2 = tk.Label(window3, text = "Type in what you want:") 
    order2.pack()
    global order2_entry
    order2_entry = tk.Entry(window3)
    order2_entry.pack()

    price2 = tk.Label(window3, text = "Type in the price:") 
    price2.pack()
    global price2_entry
    price2_entry = tk.Entry(window3)
    price2_entry.pack()
    
    
    order3 = tk.Label(window3, text = "Type in what you want:") 
    order3.pack()
    global order3_entry
    order3_entry = tk.Entry(window3)
    order3_entry.pack()
    
    price3 = tk.Label(window3, text = "Type in the price:") 
    price3.pack()
    global price3_entry
    price3_entry = tk.Entry(window3)
    price3_entry.pack()
    
    
    order4 = tk.Label(window3, text = "Type in what you want:") 
    order4.pack()
    global order4_entry
    order4_entry = tk.Entry(window3)
    order4_entry.pack()

    price4 = tk.Label(window3, text = "Type in the price:") 
    price4.pack()
    global price4_entry
    price4_entry = tk.Entry(window3)
    price4_entry.pack()
    
    
    order5 = tk.Label(window3, text = "Type in what you want:") 
    order5.pack()
    global order5_entry
    order5_entry = tk.Entry(window3)
    order5_entry.pack()

    price5 = tk.Label(window3, text = "Type in the price:") 
    price5.pack()
    global price5_entry
    price5_entry = tk.Entry(window3)
    price5_entry.pack()
    

    enter1_button = tk.Button(window3, text = "Enter", command=enter1)
    enter1_button.pack()

    window1.mainloop()   
    
def enter():
    purpose = purpose_entry.get()
    name = cname_entry.get()

    if purpose == 'yes' or purpose == 'Yes' or purpose == 'YES':
        menu()

    elif purpose == 'no'  or purpose == 'No' or purpose == 'NO':
        messagebox.showinfo("Info", f"{name} Thanks for checking us out , hope you order some other time.")

    else:
        messagebox.showerror("Failed", "Incorrect input, try again")
        
      

#Create home window
window1 = tk.Tk()
window1.title("Home Page")
window1.geometry("600x300")

#welcome note
welcome = tk.Label(window1, text = "Welcome to the PAU Cafeteria")
welcome.pack()

#Create customer name label and entry
cname = tk.Label(window1, text = "Customer Name:")
cname.pack()
cname_entry = tk.Entry(window1)
cname_entry.pack()

#ask if they want to place an order
purpose = tk.Label(window1, text = "Do you want to place an order (Enter yes/no):") 
purpose.pack()
purpose_entry = tk.Entry(window1)
purpose_entry.pack()

#create enter button
enter_button = tk.Button(window1, text = "Enter", command=enter)
enter_button.pack()

window1.mainloop()


.

# %%
#Flowchart
#Step1 : Start
#Step2 : Input User Name
#Step3 : Ask user if he/she wants to make place an order
#Step4 : If yes, proceed to step 5 else go back to step 2
#Step5 : Display Cafeteria Menu
#Step6 : Make an order
#Step7 : Sum up the prices of foodstuff acquired to find total sum
#Step8 : If total sum is >,=,< a certain amount proceed to step 9 else go to step 10
#Step9 : Give a discount to the user
#Step10 : Do not grant the user a discount
#Step11 : Stop
